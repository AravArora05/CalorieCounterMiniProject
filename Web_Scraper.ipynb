# %% [markdown]
# <a href="https://colab.research.google.com/github/AravArora05/CalorieCounterMiniProject/blob/main/Web_Scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
from bs4 import BeautifulSoup
import re

data_fields = [
    'institution.displayName',
    'institution.isPublic',
    'institution.state',
    'institution.city',
    'institution.location',
    'institution.institutionalControl',
    'institution.rankingDisplayRank',
    'institution.rankingSortRank',
    'institution.primaryPhotoThumb',
    'searchData.enrollment.rawValue',
    'searchData.engineeringRepScore.rawValue',
    'searchData.computerScienceRepScore.rawValue',
    'searchData.nursingRepScore.rawValue',
    'searchData.satAvg.displayValue',
    'searchData.actAvg.displayValue',
    'searchData.tuition.displayValue',
    'searchData.acceptanceRate.displayValue',
    'searchData.costAfterAid.displayValue',
    'searchData.hsGpaAvg.rawValue',
    'searchData.percentReceivingAid.displayValue'
]

extra_admissions_fields = ["Application Deadline", "Application Fee", "Acceptance Rate"]
extra_student_fields = ["Total Enrollment", "Live On-Campus", "Athletic Association"]

REQUEST_HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:121.0) Gecko/20100101 Firefox/121.0'
}

def traverse(data, path):
    keys = path.split('.')
    for key in keys:
        if not data or key not in data:
            return None
        data = data[key]
    return data

college_data = {}

def retrieve_page_data(url):
    print(f'Retrieving data from {url}...')
    response = requests.get(url, headers=REQUEST_HEADERS)
    json_data = response.json()

    colleges = json_data['data']['items']

    for college in colleges:
        school_name = traverse(college, 'institution.displayName')
        if not school_name:
            continue

        college_info = {}
        for field in data_fields:
            college_info[field] = traverse(college, field)

        student_life_url = 'https://www.usnews.com/best-colleges/' + traverse(college, 'institution.urlName') + '-' + traverse(college, 'institution.primaryKey') + '/student-life'
        student_life_resp = requests.get(student_life_url, headers=REQUEST_HEADERS)
        soup = BeautifulSoup(student_life_resp.text, 'html.parser')

        for field in extra_student_fields:
            dt_element = soup.find('dt', string=re.compile(field, re.IGNORECASE))
            if dt_element is None:
                college_info[field] = None
                continue

            dd_element = dt_element.find_next_sibling('dd')
            if dd_element:
                college_info[field] = dd_element.text.strip()
            else:
                college_info[field] = None

        admissions_url = 'https://www.usnews.com/best-colleges/' + traverse(college, 'institution.urlName') + '-' + traverse(college, 'institution.primaryKey') + '/applying'
        admissions_resp = requests.get(admissions_url, headers=REQUEST_HEADERS)
        soup = BeautifulSoup(admissions_resp.text, 'html.parser')

        for field in extra_admissions_fields:
            dt_element = soup.find('dt', string=re.compile(field, re.IGNORECASE))
            if dt_element is None:
                college_info[field] = None
                continue

            dd_element = dt_element.find_next_sibling('dd')
            if dd_element:
                college_info[field] = dd_element.text.strip()
            else:
                college_info[field] = None

        college_data[school_name] = college_info

    next_page_url = json_data['meta'].get('rel_next_page_url')
    if next_page_url:
        retrieve_page_data(next_page_url)
    else:
        print('All pages processed.')

retrieve_page_data('https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=1')

output_file_path = 'college_data.json'
with open(output_file_path, 'w') as json_file:
    json.dump(college_data, json_file, indent=4)
print(f"Data has been written to {output_file_path}")
# Out:
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=1...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=2...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=3...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=4...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=5...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=6...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=7...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=8...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=9...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=10...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=11...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=12...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=13...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=14...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=15...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=16...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=17...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=18...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=19...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=20...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=21...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=22...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=23...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=24...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=25...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=26...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=27...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=28...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=29...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=30...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=31...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=32...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=33...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=34...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=35...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=36...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=37...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=38...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=39...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=40...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=41...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=42...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=43...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=44...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=45...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=46...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=47...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=48...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=49...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=50...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=51...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=52...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=53...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=54...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=55...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=56...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=57...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=58...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=59...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=60...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=61...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=62...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=63...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=64...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=65...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=66...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=67...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=68...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=69...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=70...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=71...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=72...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=73...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=74...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=75...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=76...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=77...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=78...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=79...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=80...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=81...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=82...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=83...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=84...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=85...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=86...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=87...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=88...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=89...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=90...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=91...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=92...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=93...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=94...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=95...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=96...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=97...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=98...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=99...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=100...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=101...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=102...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=103...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=104...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=105...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=106...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=107...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=108...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=109...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=110...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=111...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=112...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=113...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=114...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=115...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=116...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=117...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=118...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=119...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=120...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=121...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=122...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=123...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=124...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=125...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=126...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=127...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=128...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=129...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=130...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=131...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=132...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=133...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=134...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=135...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=136...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=137...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=138...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=139...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=140...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=141...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=142...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=143...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=144...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=145...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=146...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=147...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=148...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=149...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=150...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=151...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=152...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=153...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=154...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=155...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=156...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=157...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=158...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=159...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=160...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=161...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=162...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=163...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=164...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=165...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=166...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=167...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=168...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=169...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=170...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=171...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=172...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=173...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=174...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=175...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=176...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=177...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=178...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=179...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=180...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=181...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=182...
# Retrieving data from https://www.usnews.com/best-colleges/api/search?_sort=schoolName&_sortDirection=asc&_page=183...
# All pages processed.
# Data has been written to college_data.json
